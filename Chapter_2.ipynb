# %% [markdown]
# <a href="https://colab.research.google.com/github/gstripling00/low-code-book-projects/blob/main/Chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Next, you read the dataset into a Pandas dataframe.

url = ''
heart_df= pd.read_csv(url,index_col=0)

# %%
# Next, you read the dataset into a Pandas dataframe.

url = 'https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD'
heart_df= pd.read_csv(url,index_col=0)

# %%
heart_df.head()
# Out:
#      LocationAbbr    LocationDesc GeographicLevel DataSource  \
# Year
# 2019           AK  Aleutians East          County       NVSS
# 2019           AK  Aleutians West          County       NVSS
# 2019           AK       Anchorage          County       NVSS
# 2019           AK          Bethel          County       NVSS
# 2019           AK     Bristol Bay          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59094 entries, 2019 to 2019
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LocationAbbr                59094 non-null  object
#  1   LocationDesc                59094 non-null  object
#  2   GeographicLevel             59094 non-null  object
#  3   DataSource                  59094 non-null  object
#  4   Class                       59094 non-null  object
#  5   Topic                       59094 non-null  object
#  6   Data_Value                  33087 non-null  float64
#  7   Data_Value_Unit             59094 non-null  object
#  8   Data_Value_Type             59094 non-null  object
#  9   Data_Value_Footnote_Symbol  26007 non-null  object
#  10  Data_Value_Footnote         26007 non-null  object
#  11  StratificationCategory1     59094 non-null  object
#  12  Stratification1             59094 non-null  object
# ...

# %%
import datetime as dt

# %%
url = 'https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD'
heart_df= pd.read_csv(url,index_col=0)

heart_df.head()
# Out:
#      LocationAbbr    LocationDesc GeographicLevel DataSource  \
# Year
# 2019           AK  Aleutians East          County       NVSS
# 2019           AK  Aleutians West          County       NVSS
# 2019           AK       Anchorage          County       NVSS
# 2019           AK          Bethel          County       NVSS
# 2019           AK     Bristol Bay          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# ...

# %%
heart_df = pd.read_csv('/content/heart.csv', error_bad_lines=False, engine="python")
heart_df.head()
# Out:
# <ipython-input-11-d219c15834b0>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   heart_df = pd.read_csv('/content/heart.csv', error_bad_lines=False, engine="python")
# Skipping line 41073: unexpected end of data
#    Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0  2019           AK  Aleutians East          County       NVSS
# 1  2019           AK  Aleutians West          County       NVSS
# 2  2019           AK       Anchorage          County       NVSS
# 3  2019           AK          Bethel          County       NVSS
# 4  2019           AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 1  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2  Cardiovascular Diseases  Heart Disease Mortality       255.6
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41071 entries, 0 to 41070
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        41071 non-null  int64
#  1   LocationAbbr                41071 non-null  object
#  2   LocationDesc                41071 non-null  object
#  3   GeographicLevel             41071 non-null  object
#  4   DataSource                  41071 non-null  object
#  5   Class                       41071 non-null  object
#  6   Topic                       41071 non-null  object
#  7   Data_Value                  23316 non-null  float64
#  8   Data_Value_Unit             41071 non-null  object
#  9   Data_Value_Type             41071 non-null  object
#  10  Data_Value_Footnote_Symbol  17755 non-null  object
#  11  Data_Value_Footnote         17755 non-null  object
#  12  StratificationCategory1     41071 non-null  object
# ...

# %%
heart_df.isnull().sum()
# Out:
# Year                              0
# LocationAbbr                      0
# LocationDesc                      0
# GeographicLevel                   0
# DataSource                        0
# Class                             0
# Topic                             0
# Data_Value                    17755
# Data_Value_Unit                   0
# Data_Value_Type                   0
# Data_Value_Footnote_Symbol    23316
# Data_Value_Footnote           23316
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2           0
# Stratification2                   0
# TopicID                           0
# LocationID                        0
# Y_lat                             0
# X_lon                             0
# dtype: int64

# %%
heart_df.describe()
# Out:
#           Year    Data_Value    LocationID         Y_lat         X_lon
# count  41071.0  23316.000000  41071.000000  41071.000000  41071.000000
# mean    2019.0    346.404486  22495.215675     38.686435    -92.345265
# std        0.0    150.130944  11329.714812      5.679010     16.789024
# min     2019.0      0.000000      1.000000    -14.301754   -170.719474
# 25%     2019.0    243.075000  13291.000000     34.986462    -97.517162
# 50%     2019.0    331.300000  21215.000000     38.782169    -90.449935
# 75%     2019.0    432.800000  31035.000000     41.891445    -84.163886
# max     2019.0   2030.500000  69000.000000     69.309529    145.751259

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1609: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# ---------------------------------------------------------------------------
# ...

# %%
sns.heatmap(heart_df.corr())
# Out:
# <ipython-input-33-46ac09425f7e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(heart_df.corr())
# <Axes: >

# %%
sns.displot(heart_df['Data_Value'])

# %%
sns.displot(heart_df['LocationID'])

# %%
sns.displot(heart_df['GeographicLevel'])

# %%
 sns.displot(heart_df['Stratification2'])

# %%
# Where did they die?

sns.jointplot(x='LocationID',y='Stratification2',data=heart_df)

# The title() method in matplotlib module is used to specify title of the visualization depicted and displays the title using various attributes.
plt.title('Vehicles by Month')
# Out:
# Text(0.5, 1.0, 'Vehicles by Month')

# %%
# sns.jointplot(x='GeographicLevel',y='Stratification2',data=heart_df)

sns.violinplot(x="LocationID", y="Stratification2", data=heart_df)#
# Out:
# <Axes: xlabel='LocationID', ylabel='Stratification2'>

# %%
import seaborn as sns
sns.violinplot(x="Data_Value", y="Stratification2", data=heart_df)
# Out:
# <Axes: xlabel='Data_Value', ylabel='Stratification2'>

# %%
sns.violinplot(x="Y_lat", y="Stratification2", data=heart_df)#
# Out:
# <Axes: xlabel='Y_lat', ylabel='Stratification2'>

# %%
heart_df = heart_df.drop(heart_df.columns[[6, 9, 10]], axis=1) # dfYear.columns is zero-based pd.Index

# %%
heart_df.isnull().sum()
# Out:
# LocationAbbr                0
# LocationDesc                0
# GeographicLevel             0
# DataSource                  0
# Class                       0
# Topic                       0
# Data_Value_Unit             0
# Data_Value_Type             0
# StratificationCategory1     0
# Stratification1             0
# StratificationCategory2     0
# Stratification2             0
# TopicID                     0
# LocationID                  0
# Y_lat                      18
# X_lon                      18
# dtype: int64

# %%
print ("Rows     : " ,heart_df.shape[0])
print ("Columns  : " ,heart_df.shape[1])
print ("\nFeatures : \n" ,heart_df.columns.tolist())
print ("\nUnique values :  \n",heart_df.nunique())
print ("\nMissing values :  ", heart_df.isnull().sum().values.sum())
# Out:
# Rows     :  59094
# Columns  :  16
#
# Features :
#  ['LocationAbbr', 'LocationDesc', 'GeographicLevel', 'DataSource', 'Class', 'Topic', 'Data_Value_Unit', 'Data_Value_Type', 'StratificationCategory1', 'Stratification1', 'StratificationCategory2', 'Stratification2', 'TopicID', 'LocationID', 'Y_lat', 'X_lon']
#
# Unique values :
#  LocationAbbr                 57
# LocationDesc               2022
# GeographicLevel               3
# DataSource                    1
# Class                         1
# Topic                         1
# Data_Value_Unit               1
# Data_Value_Type               2
# StratificationCategory1       1
# Stratification1               3
# StratificationCategory2       1
# Stratification2               6
# TopicID                       1
# LocationID                 3283
# Y_lat                      3282
# X_lon                      3282
# dtype: int64
#
# Missing values :   36

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Overall', 'White', 'Black', 'Hispanic',
#        'Asian and Pacific Islander', 'American Indian and Alaskan Native'],
#       dtype=object)

# %%
heart_df.GeographicLevel.unique()
# Out:
# array(['County', 'State', 'Nation'], dtype=object)

# %%
# One-Hot Encoding - Making dummy variables for categorical data

data_dummy = pd.get_dummies(heart_df[['GeographicLevel','Stratification2']], drop_first=True)

data_dummy.head()
# Out:
#       GeographicLevel_Nation  GeographicLevel_State  \
# Year
# 2019                       0                      0
# 2019                       0                      0
# 2019                       0                      0
# 2019                       0                      0
# 2019                       0                      0
#
#       Stratification2_Asian and Pacific Islander  Stratification2_Black  \
# Year
# 2019                                           0                      0
# 2019                                           0                      0
# 2019                                           0                      0
# 2019                                           0                      0
# 2019                                           0                      0
#
#       Stratification2_Hispanic  Stratification2_Overall  Stratification2_White
# Year
# 2019                         0                        1                      0
# ...

# %%
data_dummy.tail()
# Out:
#       GeographicLevel_Nation  GeographicLevel_State  \
# Year
# 2019                       0                      1
# 2019                       0                      1
# 2019                       0                      1
# 2019                       0                      1
# 2019                       0                      1
#
#       Stratification2_Asian and Pacific Islander  Stratification2_Black  \
# Year
# 2019                                           1                      0
# 2019                                           1                      0
# 2019                                           0                      0
# 2019                                           0                      0
# 2019                                           0                      0
#
#       Stratification2_Hispanic  Stratification2_Overall  Stratification2_White
# Year
# 2019                         0                        0                      0
# ...

# %%
sns.heatmap(heart_df.corr())
# Out:
# <ipython-input-62-46ac09425f7e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(heart_df.corr())
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.scatter(Stratification2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-2adb392be17b> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.scatter(Stratification2)
#       4 plt.show()
#
# NameError: name 'Stratification2' is not defined

# %%
# !pip install geopandas
# !pip install Shapely
import matplotlib as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 64.9 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import plotly.express as px

# %%
fig = px.scatter_geo(heart_df,Y_lat='Latitude',X_lon='Longitude')
fig.update_layout(title = 'Heart Disease', title_x=0.5)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-2a10f66c3c10> in <cell line: 1>()
# ----> 1 fig = px.scatter_geo(heart_df,Y_lat='Latitude',X_lon='Longitude')
#       2 fig.update_layout(title = 'Heart Disease', title_x=0.5)
#       3 fig.show()
#
# TypeError: scatter_geo() got an unexpected keyword argument 'Y_lat'

# %%
# Next, you read the dataset into a Pandas dataframe.

url = 'https://data.cdc.gov/api/views/7b9s-s8ck/rows.csv?accessType=DOWNLOAD'
chronic_df= pd.read_csv(url,index_col=0)
# Out:
# <ipython-input-9-a5d86863d3de>:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   chronic_df= pd.read_csv(url,index_col=0)

# %%
chronic_df.tail()
# Out:
#             LocationAbbr LocationDesc GeographicLevel DataSource  \
# Year
# 1999 - 2010           WY       Weston          County       NVSS
# 2010 - 2019           WY       Weston          County       NVSS
# 1999 - 2010           WY       Weston          County       NVSS
# 1999 - 2010           WY       Weston          County       NVSS
# 2010 - 2019           WY       Weston          County       NVSS
#
#                                Class                         Topic  \
# Year
# 1999 - 2010  Cardiovascular Diseases  Coronary heart disease (CHD)
# 2010 - 2019  Cardiovascular Diseases  Cardiovascular disease (CVD)
# 1999 - 2010  Cardiovascular Diseases  Cardiovascular disease (CVD)
# 1999 - 2010  Cardiovascular Diseases                 Heart failure
# 2010 - 2019  Cardiovascular Diseases                 Heart failure
#
#              Data_Value Data_Value_Unit       Data_Value_Type  \
# Year
# 1999 - 2010       -33.4               %  Total percent change
# ...

# %%
# Next, you read the dataset into a Pandas dataframe.

url = 'https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD'
chronic_df= pd.read_csv(url,index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0521b041683a> in <cell line: 4>()
#       2
#       3 url = 'https://data.cdc.gov/api/views/jiwm-ppbh/rows.csv?accessType=DOWNLOAD'
# ----> 4 chronic_df= pd.read_csv(url,index_col=0)
#
# NameError: name 'pd' is not defined

# %%
chronic_df.head()
# Out:
#      LocationAbbr    LocationDesc GeographicLevel DataSource  \
# Year
# 2019           AK  Aleutians East          County       NVSS
# 2019           AK  Aleutians West          County       NVSS
# 2019           AK       Anchorage          County       NVSS
# 2019           AK          Bethel          County       NVSS
# 2019           AK     Bristol Bay          County       NVSS
#
#                         Class                    Topic  Data_Value  \
# Year
# 2019  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 2019  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 2019  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#              Data_Value_Unit  \
# Year
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# 2019  per 100,000 population
# ...

# %%
# Next, you read the dataset into a Pandas dataframe.

url = 'https://data.cdc.gov/api/views/hk9y-quqm/rows.csv?accessType=DOWNLOAD'
covid_df= pd.read_csv(url,index_col=0)

# %%
covid_df.head()
# Out:
#             Start Date    End Date     Group  Year  Month          State  \
# Data As Of
# 04/30/2023  01/01/2020  04/29/2023  By Total   NaN    NaN  United States
# 04/30/2023  01/01/2020  04/29/2023  By Total   NaN    NaN  United States
# 04/30/2023  01/01/2020  04/29/2023  By Total   NaN    NaN  United States
# 04/30/2023  01/01/2020  04/29/2023  By Total   NaN    NaN  United States
# 04/30/2023  01/01/2020  04/29/2023  By Total   NaN    NaN  United States
#
#                  Condition Group                Condition ICD10_codes  \
# Data As Of
# 04/30/2023  Respiratory diseases  Influenza and pneumonia     J09-J18
# 04/30/2023  Respiratory diseases  Influenza and pneumonia     J09-J18
# 04/30/2023  Respiratory diseases  Influenza and pneumonia     J09-J18
# 04/30/2023  Respiratory diseases  Influenza and pneumonia     J09-J18
# 04/30/2023  Respiratory diseases  Influenza and pneumonia     J09-J18
#
#            Age Group  COVID-19 Deaths  Number of Mentions Flag
# Data As Of
# ...

# %%
https://data.wprdc.org/dataset/23fa923f-fc4e-4d4f-9be3-8a78c6674c02/resource/58e5ee1a-7428-42b1-81b7-c5a61e0719ce/download/diabetes_all_2016.csv

diabetes_all_2016.csv
